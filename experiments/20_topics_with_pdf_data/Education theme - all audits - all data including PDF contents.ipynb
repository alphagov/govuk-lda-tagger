# %% [markdown]
# # Education theme - all audits - all data including PDF contents
#
# This experiment used 8697 pages from GOV.UK related to the education theme. We extracted the following content from those pages:
#
# - Title
# - Description
# - Indexable content (i.e. the body of the document stored in Search)
# - Existing topic names
# - Exiting organisation names
# - Text from PDF attachments
#
# In order to do so, we used a combination of data from the search index and the content store. We then run Latent Dirichlet allocation (LDA) with the following parameters:
#
# - we asked for 20 topics
# - we let LDA run with 50 iterations
#
# The outcome of this experiment can be seen below. In order to run the script again, use this:
#
# ```shell
# python train_lda.py expanded_audits/all_audits_for_education_words.csv --output-topics output/withpdf_topics.csv --output-tags output/withpdf_tags.csv --output-dictionary output/withpdf_dictionary.csv  --vis-filename output/withpdf_vis.html
# ```

# %% [markdown]
# ## Dictionary
#
# LDA constructs a dictionary of words it collects from the documents. This dictionary has information on word frequencies. The dictionary for this can be seen [here](with_pdf_20_topics_dictionary.csv).

# %%
# This code is required so we can display the visualisation
import pyLDAvis
from IPython.core.display import display, HTML

# Changing the cell widths
display(HTML("<style>.container { width:100% !important; }</style>"))

# Setting the max number of rows
pd.options.display.max_rows = 30
# Setting the max number of columns
pd.options.display.max_columns = 50                                         

pyLDAvis.enable_notebook()

# %% [markdown]
# ## Interactive topic model visualisation
#
# The page below displays the topics generated by the algorithm and allows us to interact with them in order to discover what words make up each topic.

# %%
from IPython.display import HTML
HTML(filename='with_pdf_vis_20_topics.html')
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el825045084287525321354317"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# ## Sample of tagged documents
#
# Below we list a sample of the education links and the correspondent topics the algorithm chose to tag it with. This is useful in order to see if the algorithm is tagging those documents with meaningful topics.
#
# For a complete list, please see [here](with_pdf_20_topics_tags.csv).

# %% [markdown]
# ### https://www.gov.uk/government/publications/primary-school-accountability
#
# Topic 11, 70%
# Topic 10, 16%
# Topic 7, 3.5%
#
# ### https://www.gov.uk/government/news/new-funding-for-female-genital-mutilation-and-forced-marriage-prevention
#
# Topic 18, 42%
# Topic 17, 27%
# Topic 2, 12%
#
# ### https://www.gov.uk/government/statistics/child-death-reviews-year-ending-march-2014
#
# Topic 18, 40%
# Topic 0, 33%
# Topic 13, 15%
#
# ### https://www.gov.uk/government/publications/early-years-online-self-evaluation-form-sef-and-guidance-for-providers-delivering-the-early-years-foundation-stage
#
# Topic 8, 84%
# Topic 18, 7%
# Topic 13, 3%
#
# ### https://www.gov.uk/government/publications/teacher-misconduct-panel-outcome-mr-benedict-john-probert
#
# Topic 6, 87%
