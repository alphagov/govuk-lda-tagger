# %% [markdown]
# # Environment theme using phrasemachine
#
# This experiment used 18799 pages from GOV.UK related to the environment theme. We extracted the following content from those pages:
#
# - Title
# - Description
# - Indexable content (i.e. the body of the document stored in Search)
# - Existing topic names
# - Exiting organisation names
#
# In order to do so, we used a combination of data from the search index and the content store. We then run Latent Dirichlet allocation (LDA) with the following parameters:
#
# - we asked for 20 topics
# - we let LDA run with 10 iterations
# - we processed the documents using [phrasemachine](https://github.com/slanglab/phrasemachine) and lemmas.
#
# The outcome of this experiment can be seen below. In order to run the script again, use this:
#
# ```shell
# python train_lda.py --output-topics output/environment_topics.csv --output-tags output/environment_tags.csv  --vis-filename output/environment_vis.html --passes 10 --numtopics 20 --use-phrasemachine import expanded_audits/environment.csv
#
# ```

# %%
# This code is required so we can display the visualisation
import pyLDAvis
from IPython.core.display import display, HTML

# Changing the cell widths
display(HTML("<style>.container { width:100% !important; }</style>"))

# Setting the max number of rows
pd.options.display.max_rows = 30
# Setting the max number of columns
pd.options.display.max_columns = 50                                         

pyLDAvis.enable_notebook()

# %% [markdown]
# ## Interactive topic model visualisation
#
# The page below displays the topics generated by the algorithm and allows us to interact with them in order to discover what words make up each topic.

# %%
from IPython.display import HTML
HTML(filename='environment_vis.html')
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el7755047054804002587937078"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# ## Sample of tagged documents
#
# Below we list a sample of the education links and the correspondent topics the algorithm chose to tag it with. This is useful in order to see if the algorithm is tagging those documents with meaningful topics.
#
# For a complete list, please see [here](environment_tags.csv).
#
# In order to check the topics by their number, please use this CSV file [here](environment_topics.csv).

# %% [markdown]
# ### https://www.gov.uk//government/news/government-announces-action-to-improve-implementation-of-the-habitats-and-wild-birds-directives
# - Topic 11 (38%)
# - Topic 17 (31%)
# - Topic 19 (18%)
#
# ### https://www.gov.uk//government/speeches/hm-treasury-analysis-on-the-eu-referendum-george-osbornes-speech
# - Topic 18 (66%)
# - Topic 17 (28%)
# - Topic 7 (5%)
#
# ### https://www.gov.uk//government/publications/cpet-sustainable-palm-oil-newsletter-issue-9
# - Topic 7 (87%)
# - Topic 8 (11%)
#
# ### https://www.gov.uk//guidance/import-tariff-quota-from-ukraine
# - Topic 16 (92%)
# - Topic 9 (7%)
#
# ### https://www.gov.uk//government/publications/understanding-radiation-and-explaining-the-risk
# - Topic 10 (47%)
# - Topic 15 (38%)
#
# ### https://www.gov.uk//government/statistics/road-fuel-prices-21-september-2015
# - Topic 18 (73%)
# - Topic 0 (17%)
# - Topic 10 (6%)
#
# ### https://www.gov.uk//government/publications/files-relating-to-climate-change-from-1983-to-1989-reference-12-0298
# - Topic 6 (63%)
# - Topic 0 (28%)
#
# ### https://www.gov.uk//guidance/control-and-management-of-ballast-water
# - Topic 1 (82%)
# - Topic 12 (4%)
# - Topic 2 (3%)
#
# ### https://www.gov.uk//government/consultations/information-requirements-for-monitoring-and-evaluation-of-smart-meters
# - Topic 0 (82%)
# - Topic 9 (5%)
# - Topic 8 (3%)
#
# ### https://www.gov.uk//government/news/uk-and-brazil-call-for-action-on-food-prices
# - Topic 17 (85%)
# - Topic 10 (11%)
# - Topic 7 (2%)
#
# ### https://www.gov.uk//government/news/5-million-for-agricultural-innovation
# - Topic 19 (91%)
# - Topic 17 (6%)
#
# ### https://www.gov.uk//government/publications/registration-of-new-town-and-village-greens-2013-survey
# - Topic 16 (75%)
# - Topic 17 (21%)
# - Topic 4 (2%)
#
# ### https://www.gov.uk//government/publications/marine-strategy-part-three-uk-programme-of-measures
# - Topic 11 (98%)
#
# ### https://www.gov.uk//government/publications/the-cost-of-away-days-and-team-building-reference-12-0315
# - Topic 11 (89%)
# - Topic 0 (6%)
#
# ### https://www.gov.uk//government/news/local-councils-to-receive-millions-in-business-rates-from-shale-gas-developments
# - Topic 13 (66%)
# - Topic 17 (19%)
# - Topic 0 (5%)
#
# ### https://www.gov.uk//government/news/brown-field-allowance-sparks-new-wave-of-oil-investment
# - Topic 0 (80%)
# - Topic 17 (10%)
# - Topic 19 (3%)
#
# ### https://www.gov.uk//government/publications/countryside-stewardship-statement-of-priorities-northamptonshire-uplands-nca095
# - Topic 14 (98%)
#
# ### https://www.gov.uk//guidance/industrial-fibre-crops
# - Topic 2 (76%)
# - Topic 15 (13%)
# - Topic 17 (3%)
#
# ### https://www.gov.uk//government/publications/energy-efficient-products-helping-us-cut-energy-use
# - Topic 13 (57%)
# - Topic 7 (33%)
# - Topic 2 (8%)
#
# ### https://www.gov.uk//government/news/illegal-angler-catches-487-penalty
# - Topic 9 (83%)
# - Topic 18 (5%)
# - Topic 2 (4%)
